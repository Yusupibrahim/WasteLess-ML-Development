# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow import keras
import pickle

# %%
df = pd.read_excel('LabeledDatasetsh5.xlsx')
df
# Out:
#        Unnamed: 0  ayam-dagingT  ikan-seafoodT  tahu-tempe-telurT    sayurT  \
# 0               0      2.956622       0.263790          -0.804028 -0.164989
# 1               1      2.212821      -0.992702           0.592624 -0.025410
# 2               2      3.235548       0.310327           0.266738 -0.118462
# 3               3      2.305796      -0.527335          -0.431588  0.160695
# 4               4      3.049597      -0.015431          -1.316134 -0.583724
# ...           ...           ...            ...                ...       ...
# 12336       12336     -0.158045       0.077643           0.778844 -0.118462
# 12337       12337     -0.436970      -1.364996           0.871954  0.719008
# 12338       12338     -0.483458       0.496473          -0.152257 -0.769829
# 12339       12339      0.306831       0.124180          -0.571253  0.905113
# 12340       12340      0.306831       0.868767          -0.804028 -0.537198
#
#         sambalT  nasi-mie-pastaT  sop-soto-baksoT  kue-rotiT  jajanan-pasarT  \
# 0      0.442037        -1.222774        -1.377233  -0.476528       -1.129483
# 1     -0.397436        -0.851014        -0.297525  -0.663209       -0.711423
# 2      0.022300         0.821907        -0.250581  -1.316594       -0.618521
# 3     -1.096997         0.914847        -1.142514   0.270197       -0.061108
# 4     -0.397436        -1.176304         0.923014   0.083516        0.124696
# ...         ...              ...              ...        ...             ...
# 12336 -0.210887         0.124856         0.547463   0.830241       -0.664972
# 12337 -1.330184        -0.293374        -0.813907   0.410208        0.217599
# 12338 -0.350799        -1.222774        -1.048626   0.316867       -0.943679
# 12339 -0.723898         0.636027         0.829126   0.130186       -0.154010
# 12340 -1.376821        -1.036894         0.359688   0.550219       -0.897228
#
#        puding-jeliT  keripik-kerupukT  buah-minumanT  kmeans_12
# 0         -0.342031         -1.081495      -1.044021          6
# 1          0.078681          0.454677       0.775717          6
# 2         -0.061556          0.361576      -0.697405          6
# 3         -0.061556         -0.057380       0.169138          6
# 4         -0.108302         -0.755640       0.039156          6
# ...             ...               ...            ...        ...
# 12336     -0.622505         -0.336684       2.638783          2
# 12337     -0.248539         -1.174596       1.642259          2
# 12338     -0.575759         -1.174596       2.552128          2
# 12339      0.125427          0.128823       2.898745          2
# 12340     -0.809488          0.082272       1.902222          2
#
# [12341 rows x 14 columns]

# %%
X = df.drop("kmeans_12", axis=1)
X = X.drop("Unnamed: 0",axis=1 )
y = df["kmeans_12"]

# %%
X
# Out:
#        ayam-dagingT  ikan-seafoodT  tahu-tempe-telurT    sayurT   sambalT  \
# 0          2.956622       0.263790          -0.804028 -0.164989  0.442037
# 1          2.212821      -0.992702           0.592624 -0.025410 -0.397436
# 2          3.235548       0.310327           0.266738 -0.118462  0.022300
# 3          2.305796      -0.527335          -0.431588  0.160695 -1.096997
# 4          3.049597      -0.015431          -1.316134 -0.583724 -0.397436
# ...             ...            ...                ...       ...       ...
# 12336     -0.158045       0.077643           0.778844 -0.118462 -0.210887
# 12337     -0.436970      -1.364996           0.871954  0.719008 -1.330184
# 12338     -0.483458       0.496473          -0.152257 -0.769829 -0.350799
# 12339      0.306831       0.124180          -0.571253  0.905113 -0.723898
# 12340      0.306831       0.868767          -0.804028 -0.537198 -1.376821
#
#        nasi-mie-pastaT  sop-soto-baksoT  kue-rotiT  jajanan-pasarT  \
# 0            -1.222774        -1.377233  -0.476528       -1.129483
# 1            -0.851014        -0.297525  -0.663209       -0.711423
# 2             0.821907        -0.250581  -1.316594       -0.618521
# 3             0.914847        -1.142514   0.270197       -0.061108
# 4            -1.176304         0.923014   0.083516        0.124696
# ...                ...              ...        ...             ...
# 12336         0.124856         0.547463   0.830241       -0.664972
# 12337        -0.293374        -0.813907   0.410208        0.217599
# 12338        -1.222774        -1.048626   0.316867       -0.943679
# 12339         0.636027         0.829126   0.130186       -0.154010
# 12340        -1.036894         0.359688   0.550219       -0.897228
#
#        puding-jeliT  keripik-kerupukT  buah-minumanT
# 0         -0.342031         -1.081495      -1.044021
# 1          0.078681          0.454677       0.775717
# 2         -0.061556          0.361576      -0.697405
# 3         -0.061556         -0.057380       0.169138
# 4         -0.108302         -0.755640       0.039156
# ...             ...               ...            ...
# 12336     -0.622505         -0.336684       2.638783
# 12337     -0.248539         -1.174596       1.642259
# 12338     -0.575759         -1.174596       2.552128
# 12339      0.125427          0.128823       2.898745
# 12340     -0.809488          0.082272       1.902222
#
# [12341 rows x 12 columns]

# %%
x_train , x_test, y_train,y_test = train_test_split(X,y, test_size=0.2)

# %%
model = keras.models.Sequential()
model.add(keras.Input(shape=(12)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(12, activation='softmax'))
model.build()
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                832
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 3,308
# Trainable params: 3,308
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
loss = tf.keras.losses.SparseCategoricalCrossentropy()
optim = keras.optimizers.Adam(learning_rate=0.001)
metrics = ["accuracy"]

# %%
model.compile(loss=loss, optimizer=optim, metrics=["accuracy"])

# %%
batch_size = 64
epochs = 20
model.fit(x_train,y_train, batch_size=batch_size, epochs=epochs)
# Out:
# Epoch 1/20
# 155/155 [==============================] - 2s 5ms/step - loss: 1.2176 - accuracy: 0.7309
# Epoch 2/20
# 155/155 [==============================] - 1s 5ms/step - loss: 0.0818 - accuracy: 0.9995
# Epoch 3/20
# 155/155 [==============================] - 1s 4ms/step - loss: 0.0229 - accuracy: 0.9999
# Epoch 4/20
# 155/155 [==============================] - 1s 5ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 5/20
# 155/155 [==============================] - 1s 5ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 6/20
# 155/155 [==============================] - 1s 5ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 7/20
# 155/155 [==============================] - 1s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 8/20
# 155/155 [==============================] - 1s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 9/20
# 155/155 [==============================] - 1s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 10/20
# 155/155 [==============================] - 1s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 11/20
# 155/155 [==============================] - 1s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 12/20
# 155/155 [==============================] - 1s 4ms/step - loss: 9.8679e-04 - accuracy: 1.0000
# Epoch 13/20
# 155/155 [==============================] - 1s 4ms/step - loss: 8.2586e-04 - accuracy: 1.0000
# Epoch 14/20
# 155/155 [==============================] - 1s 5ms/step - loss: 6.9920e-04 - accuracy: 1.0000
# Epoch 15/20
# 155/155 [==============================] - 1s 5ms/step - loss: 5.9722e-04 - accuracy: 1.0000
# Epoch 16/20
# 155/155 [==============================] - 1s 4ms/step - loss: 5.1539e-04 - accuracy: 1.0000
# Epoch 17/20
# 155/155 [==============================] - 1s 5ms/step - loss: 4.4649e-04 - accuracy: 1.0000
# Epoch 18/20
# 155/155 [==============================] - 1s 5ms/step - loss: 3.8919e-04 - accuracy: 1.0000
# Epoch 19/20
# 155/155 [==============================] - 1s 4ms/step - loss: 3.4126e-04 - accuracy: 1.0000
# Epoch 20/20
# 155/155 [==============================] - 1s 4ms/step - loss: 3.0051e-04 - accuracy: 1.0000

# %%
#loss = model.evaluate(x_test,y_test, verbose=0)
#print(loss)
# Out:
# [0.0003109194221906364, 1.0]
